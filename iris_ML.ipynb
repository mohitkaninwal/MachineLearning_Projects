# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
columns= ['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm','Species']
data= pd.read_csv('Iris.csv',names=columns)

# %%
data.sample(5)
# Out:
#     SepalLengthCm SepalWidthCm PetalLengthCm PetalWidthCm          Species
# 128           6.1          3.0           4.9          1.8   Iris-virginica
# 5             5.0          3.6           1.4          0.2      Iris-setosa
# 27            5.0          3.4           1.6          0.4      Iris-setosa
# 125           6.7          3.3           5.7          2.1   Iris-virginica
# 63            6.0          2.2           4.0          1.0  Iris-versicolor

# %%
data.describe()
# Out:
#        SepalLengthCm SepalWidthCm PetalLengthCm PetalWidthCm      Species
# count            151          151           151          151          151
# unique            36           24            44           23            4
# top              5.0          3.0           1.5          0.2  Iris-setosa
# freq              10           26            14           28           50

# %%
data["Species"] = data["Species"].astype("category")
sns.pairplot(data, hue="Species")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-30e9fe3ddde1> in <cell line: 0>()
#       1 data["Species"] = data["Species"].astype("category")
# ----> 2 sns.pairplot(data, hue="Species")
#       3 plt.show()
#
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2117     # Set up the PairGrid
#    2118     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2119     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2120                     hue_order=hue_order, palette=palette, corner=corner,
#    2121                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py in __init__(self, data, hue, vars, x_vars, y_vars, hue_order, palette, hue_kws, corner, diag_sharey, height, aspect, layout_pad, despine, dropna)
#    1270
#    1271         if not x_vars:
# -> 1272             raise ValueError("No variables found for grid columns.")
#    1273         if not y_vars:
#    1274             raise ValueError("No variables found for grid rows.")
#
# ValueError: No variables found for grid columns.

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test= train_test_split(data.drop('Species',axis=1),data['Species'],test_size=0.2)

# %%
X_train
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 76    77            6.8           2.8            4.8           1.4
# 55    56            5.7           2.8            4.5           1.3
# 95    96            5.7           3.0            4.2           1.2
# 111  112            6.4           2.7            5.3           1.9
# 110  111            6.5           3.2            5.1           2.0
# ..   ...            ...           ...            ...           ...
# 122  123            7.7           2.8            6.7           2.0
# 138  139            6.0           3.0            4.8           1.8
# 105  106            7.6           3.0            6.6           2.1
# 79    80            5.7           2.6            3.5           1.0
# 128  129            6.4           2.8            5.6           2.1
#
# [105 rows x 5 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_train= scaler.fit_transform(X_train)
X_test= scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.00555328,  1.05989586, -0.63567206,  0.51362422,  0.20215236],
#        [-0.49535281, -0.23965798, -0.63567206,  0.3459645 ,  0.07193151],
#        [ 0.43759867, -0.23965798, -0.18007092,  0.17830478, -0.05828933],
#        [ 0.81077926,  0.58733083, -0.86347262,  0.79305709,  0.85325659],
#        [ 0.78745547,  0.70547209,  0.27553021,  0.68128394,  0.98347744],
#        [ 1.30057879,  0.58733083, -0.63567206,  0.96071681,  1.24391913],
#        [-1.47495186, -1.8936356 , -0.18007092, -1.554179  , -1.49071863],
#        [ 0.22768459,  0.9417546 ,  0.04772964,  0.45773765,  0.33237321],
#        [-1.7548373 , -1.18478805, -0.18007092, -1.38651927, -1.36049779],
#        [-0.5186766 ,  0.70547209, -0.63567206,  0.40185108,  0.33237321],
#        [ 1.25393121,  1.76874341, -0.63567206,  1.24014968,  0.85325659],
#        [-0.37873387, -1.06664679, -2.45807658, -0.21290123, -0.31873102],
#        [ 0.29765595, -0.4759405 , -1.31907375,  0.06653164,  0.07193151],
#        [-1.45162807, -0.12151672,  2.09793474, -1.49829242, -1.36049779],
#        [-0.07552464,  0.23290705, -0.63567206,  0.45773765, -0.05828933],
#        [-1.03179991, -0.83036427,  2.3257353 , -1.3306327 , -1.49071863],
#        [ 0.62418896,  0.46918957, -0.40787149,  0.96071681,  0.72303574],
#        [-1.10177127, -1.42107057,  0.27553021, -1.27474613, -1.36049779],
#        [-1.61489458, -1.06664679,  0.73113134, -1.3306327 , -1.36049779],
#        [-1.54492322, -0.59408176,  1.41453304, -1.3306327 , -1.36049779],
#        [-0.89185719, -1.77549434, -0.18007092, -1.44240585, -1.36049779],
#        [ 1.18395985,  0.23290705, -0.18007092,  0.5695108 ,  0.72303574],
#        [-1.14841884, -0.83036427,  0.95893191, -1.3306327 , -1.36049779],
#        [-1.05512369, -0.59408176,  0.73113134, -1.3306327 , -1.1000561 ],
#        [ 1.13731228,  1.5324609 ,  0.27553021,  1.1842631 ,  0.72303574],
#        [-1.70818973, -1.53921182,  0.04772964, -1.3306327 , -1.36049779],
#        [ 1.0906647 ,  0.46918957, -0.86347262,  0.5695108 ,  0.72303574],
#        [ 1.23060742,  1.5324609 , -0.18007092,  1.07248996,  0.46259405],
#        [ 1.67375938,  0.35104831,  0.73113134,  0.84894366,  1.37413997],
#        [-0.30876251,  0.23290705, -0.40787149,  0.45773765,  0.20215236],
#        [-1.19506642, -1.06664679, -0.18007092, -1.27474613, -1.36049779],
#        [ 1.06734092,  2.12316719, -0.63567206,  1.57546912,  0.98347744],
#        [ 1.44052151,  0.11476579, -0.18007092,  0.51362422,  0.72303574],
#        [ 0.67083654,  2.00502593, -0.18007092,  1.51958254,  1.11369828],
#        [ 0.06441808, -0.23965798, -1.09127319, -0.21290123, -0.31873102],
#        [ 1.20728364,  0.58733083, -0.63567206,  0.96071681,  1.11369828]])

# %%
from sklearn.svm import SVC
model_svc= SVC()
model_svc.fit(X_train,y_train)
# Out:
# SVC()

# %%
pred1= model_svc.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_score(y_test,pred1)
# Out:
# 1.0

# %%
from sklearn.linear_model import LogisticRegression
model_lr= LogisticRegression()
model_lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
pred2=model_lr.predict(X_test)
accuracy_score(y_test,pred2)
# Out:
# 0.9777777777777777

# %%
from sklearn.tree import DecisionTreeClassifier
model_dt= DecisionTreeClassifier()
model_dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred3=model_dt.predict(X_test)
accuracy_score(y_test,pred3)
# Out:
# 0.9777777777777777
